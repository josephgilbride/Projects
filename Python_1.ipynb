# %% [markdown]
# # Instructions:

# %% [markdown]
# Please answer the following questions as thoroughly as possible to produce correct output and to clearly interpret the results if the question asks for it.

# %% [markdown]
# ## Question 1 (50 points)

# %% [markdown]
# ### Import neccessary libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the dataset as excel 'titanic.xls'

# %%
# %cd /Users/josephgilbride/Downloads/
df = pd.read_csv("titanic.csv")
# Out:
# /Users/josephgilbride/Downloads

# %% [markdown]
# ### Show the head of the dataframe and briefly explain the data

# %%
df.head()

#pclass - 'passenger class' (1st, 2nd, 3rd)
#survived - True or False
#name - name of passenger
#sex - gender
#age
#sibsp - number of siblings or spouse onboard
#parch - number of parents or children onboard
#ticket - ticket number
#fare - price paid
#cabin - cabin of stay
#embarked - port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
#boat - lifeboat
#body - body identification
#home.dest - home / destination
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# ### Return some info on the data and briefly explain what the categories mean

# %%
df.info()

# with the document only being 1310 rows long, the categories of data were stored as floats or objects.  These are high memory categories
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
# pclass       1309 non-null float64
# survived     1309 non-null float64
# name         1309 non-null object
# sex          1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null float64
# parch        1309 non-null float64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %% [markdown]
# ### 'Describe' the main statistical features of the data

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# ### Include 50% to 100% percentile with 5% increments for the 'age' column in the describe method output

# %%
range1 = np.arange(.5, 1, .05)
df['age'].describe(percentiles = range1)
# Out:
# count    1046.000000
# mean       29.881135
# std        14.413500
# min         0.166700
# 50%        28.000000
# 55.0%      30.000000
# 60.0%      31.000000
# 65.0%      33.000000
# 70.0%      36.000000
# 75.0%      39.000000
# 80.0%      42.000000
# 85.0%      45.000000
# 90.0%      50.000000
# 95.0%      57.000000
# max        80.000000
# Name: age, dtype: float64

# %% [markdown]
# ### What is the 80% percentile of the 'age' column?

# %%
range2 = np.arange(.8, 1)
answer = df['age'].describe(percentiles = range2)
answer.iloc[5:6]
# Out:
# 80%    42.0
# Name: age, dtype: float64

# %% [markdown]
# ### Create a sub dataframe where the age of passengers is above the 80% percentile calculated above

# %%
ages = df['age']>=42
answer = df[ages]
answer.sort_values(by='age', ascending = False)
# Out:
#       pclass  survived                                               name  \
# 14       1.0       1.0               Barkworth, Mr. Algernon Henry Wilson
# 61       1.0       1.0  Cavendish, Mrs. Tyrell William (Julia Florence...
# 1235     3.0       0.0                                Svensson, Mr. Johan
# 135      1.0       0.0                          Goldschmidt, Mr. George B
# 9        1.0       0.0                            Artagaveytia, Mr. Ramon
# 727      3.0       0.0                               Connors, Mr. Patrick
# 506      2.0       0.0                        Mitchell, Mr. Henry Michael
# 81       1.0       0.0                       Crosby, Capt. Edward Gifford
# 285      1.0       0.0                                 Straus, Mr. Isidor
# 594      2.0       0.0                              Wheadon, Mr. Edward H
# 782      3.0       0.0                                   Duane, Mr. Frank
# 221      1.0       0.0                     Ostby, Mr. Engelhart Cornelius
# ...

# %% [markdown]
# ### Count the number of passengers in first class

# %%
firstclass = df['pclass']==1.0
answer2 = df[firstclass]
answer2a = answer2.count()
answer2a.iloc[0:1,]
# Out:
# pclass    323
# dtype: int64

# %% [markdown]
# ### Create a new column called 'older than 90% percentile' where it's true/false if the passenger is older/younger than the 90% percentile

# %%
older90 = df['age']>50
older90a = older90.to_frame()
older90b = older90a.rename(columns={"age": "olderthan90"})
df2 = pd.concat([df, older90b], axis=1)
df2
# Out:
#       pclass  survived                                               name  \
# 0        1.0       1.0                      Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                     Allison, Master. Hudson Trevor
# 2        1.0       0.0                       Allison, Miss. Helen Loraine
# 3        1.0       0.0               Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1.0       1.0                                Anderson, Mr. Harry
# 6        1.0       1.0                  Andrews, Miss. Kornelia Theodosia
# 7        1.0       0.0                             Andrews, Mr. Thomas Jr
# 8        1.0       1.0      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1.0       0.0                            Artagaveytia, Mr. Ramon
# 10       1.0       0.0                             Astor, Col. John Jacob
# 11       1.0       1.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %% [markdown]
# ### Group the 'fare' column by the class of passenger and get the mean fare price for each class

# %%
df3 = df.groupby(["pclass"]).mean()
classfares = df3.iloc[0:,4:5]
classfares
# Out:
#              fare
# pclass
# 1.0     87.508992
# 2.0     21.179196
# 3.0     13.302889

# %% [markdown]
# ### Plot the bar chart for the avg fare grouped by class

# %%
classfares.plot(kind = 'bar')

# %% [markdown]
# ### Getting the number of outliers: define the upper bound and lower bound for the 'fare' column at 95% or 5% and count how many passengers are considered outliers

# %%
range1 = np.arange(.95, 1, .05)
df['fare'].describe(percentiles = range1)
outliers = df['fare']>133.65
answer4 = df[outliers].count()
answer4.iloc[0:1,]
# Out:
# pclass    65
# dtype: int64

# %% [markdown]
# ### Replace outliers in the dataframe by the mean of the 'fare' column

# %%
means = df['fare'].mean()
df.loc[df['fare'] > 133.65, 'fare']  = means
df
# Out:
#       pclass  survived                                               name  \
# 0        1.0       1.0                      Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                     Allison, Master. Hudson Trevor
# 2        1.0       0.0                       Allison, Miss. Helen Loraine
# 3        1.0       0.0               Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1.0       1.0                                Anderson, Mr. Harry
# 6        1.0       1.0                  Andrews, Miss. Kornelia Theodosia
# 7        1.0       0.0                             Andrews, Mr. Thomas Jr
# 8        1.0       1.0      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1.0       0.0                            Artagaveytia, Mr. Ramon
# 10       1.0       0.0                             Astor, Col. John Jacob
# 11       1.0       1.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %% [markdown]
# ## Question 2 (50 points)

# %% [markdown]
# ### Load the contents of 'titanic2.csv', look at the head of the data for its structure and combine it with the previous dataframe

# %%
dft = pd.read_csv("titanic2.csv")
dftitanic = pd.concat([df, dft], axis=0)
dftitanic
# Out:
#       pclass  survived                                               name  \
# 0        1.0       1.0                      Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                     Allison, Master. Hudson Trevor
# 2        1.0       0.0                       Allison, Miss. Helen Loraine
# 3        1.0       0.0               Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1.0       1.0                                Anderson, Mr. Harry
# 6        1.0       1.0                  Andrews, Miss. Kornelia Theodosia
# 7        1.0       0.0                             Andrews, Mr. Thomas Jr
# 8        1.0       1.0      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1.0       0.0                            Artagaveytia, Mr. Ramon
# 10       1.0       0.0                             Astor, Col. John Jacob
# 11       1.0       1.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %% [markdown]
# ### Plot a scatter plot of 'age' vs 'fare' for your data and calculate the correlation between these two columns

# %%
agefare = dftitanic[['age', 'fare']]
plt.scatter(agefare['age'], agefare['fare'])
agefare.corr(method = 'pearson').iloc[1:,0:1]
# Out:
#            age
# fare  0.194496

# %% [markdown]
# ### Drop 'name', 'cabin', 'boat', 'body','home.dest', 'embarked', 'ticket' columns

# %%
dftitanic2 = dftitanic.drop(['name', 'cabin', 'boat', 'body', 'home.dest', 'embarked', 'ticket'], axis=1)
dftitanic2 = dftitanic2.iloc[0:1309,]
dftitanic2
# Out:
#       pclass  survived     sex      age  sibsp  parch       fare
# 0        1.0       1.0  female  29.0000    0.0    0.0  33.295479
# 1        1.0       1.0    male   0.9167    1.0    2.0  33.295479
# 2        1.0       0.0  female   2.0000    1.0    2.0  33.295479
# 3        1.0       0.0    male  30.0000    1.0    2.0  33.295479
# 4        1.0       0.0  female  25.0000    1.0    2.0  33.295479
# 5        1.0       1.0    male  48.0000    0.0    0.0  26.550000
# 6        1.0       1.0  female  63.0000    1.0    0.0  77.958300
# 7        1.0       0.0    male  39.0000    0.0    0.0   0.000000
# 8        1.0       1.0  female  53.0000    2.0    0.0  51.479200
# 9        1.0       0.0    male  71.0000    0.0    0.0  49.504200
# 10       1.0       0.0    male  47.0000    1.0    0.0  33.295479
# 11       1.0       1.0  female  18.0000    1.0    0.0  33.295479
# 12       1.0       1.0  female  24.0000    0.0    0.0  69.300000
# ...

# %% [markdown]
# # Filling missing data in 'age' column by using an educated guess:

# %% [markdown]
# ### Write a function that takes two columns, 'age' and 'pclass', as input and depending on which pclass, if the age is NaN (command: pd.isnull(age)   ) it returns age 40, 30 or 25. For example, if input is [NaN, 1], it returns age = 40

# %%
def fill_ages(df): 
 
    mask = (df['pclass'] == 1) & (df['age'] != df['age'])
    mask2 = (df['pclass'] == 2) & (df['age'] != df['age'])
    mask3 = (df['pclass'] == 3) & (df['age'] != df['age'])

    
    if mask.any() == True:
        df['age'] = df['age'].mask(mask,40)
   
    if mask2.any() == True:
        df['age'] = df['age'].mask(mask2,30)
    
    if mask3.any() == True:
        df['age'] = df['age'].mask(mask3,25)

# %% [markdown]
# ### Use apply to clean up age database for NaN using the function created above

# %%
fill_ages(dftitanic2)

dftitanic2
# Out:
#       pclass  survived     sex      age  sibsp  parch       fare
# 0        1.0       1.0  female  29.0000    0.0    0.0  33.295479
# 1        1.0       1.0    male   0.9167    1.0    2.0  33.295479
# 2        1.0       0.0  female   2.0000    1.0    2.0  33.295479
# 3        1.0       0.0    male  30.0000    1.0    2.0  33.295479
# 4        1.0       0.0  female  25.0000    1.0    2.0  33.295479
# 5        1.0       1.0    male  48.0000    0.0    0.0  26.550000
# 6        1.0       1.0  female  63.0000    1.0    0.0  77.958300
# 7        1.0       0.0    male  39.0000    0.0    0.0   0.000000
# 8        1.0       1.0  female  53.0000    2.0    0.0  51.479200
# 9        1.0       0.0    male  71.0000    0.0    0.0  49.504200
# 10       1.0       0.0    male  47.0000    1.0    0.0  33.295479
# 11       1.0       1.0  female  18.0000    1.0    0.0  33.295479
# 12       1.0       1.0  female  24.0000    0.0    0.0  69.300000
# ...

# %% [markdown]
# ### In the 'fare' column, isolate and display the row where there is NaN

# %%
mask4 = (dftitanic2['fare'] != dftitanic2['fare'])
dftitanic2[mask4]
# Out:
#       pclass  survived   sex   age  sibsp  parch  fare
# 1225     3.0       0.0  male  60.5    0.0    0.0   NaN

# %% [markdown]
# ### Using apply fuction, convert the data in 'sex' column to zeros and ones: if female, replace by 1, otherwise by 0

# %%
dftitanic2['sex'].replace('female', 1,inplace=True)
dftitanic2['sex'].replace('male', 0,inplace=True)
dftitanic2
# Out:
#       pclass  survived  sex      age  sibsp  parch       fare
# 0        1.0       1.0    1  29.0000    0.0    0.0  33.295479
# 1        1.0       1.0    0   0.9167    1.0    2.0  33.295479
# 2        1.0       0.0    1   2.0000    1.0    2.0  33.295479
# 3        1.0       0.0    0  30.0000    1.0    2.0  33.295479
# 4        1.0       0.0    1  25.0000    1.0    2.0  33.295479
# 5        1.0       1.0    0  48.0000    0.0    0.0  26.550000
# 6        1.0       1.0    1  63.0000    1.0    0.0  77.958300
# 7        1.0       0.0    0  39.0000    0.0    0.0   0.000000
# 8        1.0       1.0    1  53.0000    2.0    0.0  51.479200
# 9        1.0       0.0    0  71.0000    0.0    0.0  49.504200
# 10       1.0       0.0    0  47.0000    1.0    0.0  33.295479
# 11       1.0       1.0    1  18.0000    1.0    0.0  33.295479
# 12       1.0       1.0    1  24.0000    0.0    0.0  69.300000
# 13       1.0       1.0    1  26.0000    0.0    0.0  78.850000
# ...

# %% [markdown]
# ### Display the top rows for 'sex' column

# %%
dftitanic2.head()
# Out:
#    pclass  survived  sex      age  sibsp  parch       fare
# 0     1.0       1.0    1  29.0000    0.0    0.0  33.295479
# 1     1.0       1.0    0   0.9167    1.0    2.0  33.295479
# 2     1.0       0.0    1   2.0000    1.0    2.0  33.295479
# 3     1.0       0.0    0  30.0000    1.0    2.0  33.295479
# 4     1.0       0.0    1  25.0000    1.0    2.0  33.295479

# %% [markdown]
# ### Confirm that the contents of the 'sex' column are integers by showing the type of one content (zero's index, first, etc) or using the info command

# %%
dftitanic2['sex'].astype('int32')
dftitanic2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 7 columns):
# pclass      1309 non-null float64
# survived    1309 non-null float64
# sex         1309 non-null int64
# age         1309 non-null float64
# sibsp       1309 non-null float64
# parch       1309 non-null float64
# fare        1308 non-null float64
# dtypes: float64(6), int64(1)
# memory usage: 81.8 KB

# %% [markdown]
# ### In 'fare' column, replace NaN with the mean of the column

# %%
dftitanic2['fare'].fillna((dftitanic['fare'].mean()), inplace=True)

# %%
dftitanic2.iloc[1225,]
# Out:
# pclass       3.000000
# survived     0.000000
# sex          0.000000
# age         60.500000
# sibsp        0.000000
# parch        0.000000
# fare        24.083436
# Name: 1225, dtype: float64

# %% [markdown]
# ### Drop any leftover NaN in the dataframe

# %%
dftitanic2.isnull().any()
# Out:
# pclass      False
# survived    False
# sex         False
# age         False
# sibsp       False
# parch       False
# fare        False
# dtype: bool

# %% [markdown]
# ### Display the head of cleaned dataframe

# %%
dftitanic2.head()
# Out:
#    pclass  survived  sex      age  sibsp  parch       fare
# 0     1.0       1.0    1  29.0000    0.0    0.0  33.295479
# 1     1.0       1.0    0   0.9167    1.0    2.0  33.295479
# 2     1.0       0.0    1   2.0000    1.0    2.0  33.295479
# 3     1.0       0.0    0  30.0000    1.0    2.0  33.295479
# 4     1.0       0.0    1  25.0000    1.0    2.0  33.295479

# %% [markdown]
# # QED!
